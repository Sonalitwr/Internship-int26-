# %% [markdown]
# # CUSTOMER RETENTION ANALYSIS

# %% [markdown]
# ## 1. Importing Libraries

# %%
#importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


#importing warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Reading Dataset

# %%
df = pd.read_csv("customer_retention_dataset1.csv")
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %% [markdown]
# ## 3. Checking basic information of data

# %%
print(df.columns)
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.shape
# Out:
# (269, 71)

# %% [markdown]
# ## 4. Checking null values

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
#heatmap for checking all null values 

plt.figure(figsize=(14,14))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 5. Visualizing for analysis

# %% [markdown]
# we will be plotting bar graphs and pie charts for all unique values in all columns

# %% [markdown]
# 5.1 Gender

# %%
df['1Gender of respondent'].value_counts()
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %%
sns.countplot(y="1Gender of respondent",data=df)
plt.title("GENDER COMPOSITION")
plt.grid()
plt.ylabel('Gender')
plt.xlabel("count")
plt.show()

# %% [markdown]
# 5.2 Age

# %%
df["2 How old are you? "].value_counts()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64

# %%
sns.countplot(y="2 How old are you? ", data=df)
plt.title("Age ")
plt.ylabel('Age group')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.3 Area composition

# %%
df["3 Which city do you shop online from?"].value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Ghaziabad        18
# Solan            18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %%
sns.countplot(y="3 Which city do you shop online from?", data=df)
plt.title("Area")
plt.ylabel('name of city')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.4 Pincode

# %%
df['4 What is the Pin Code of where you shop online from?'].value_counts()
# Out:
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 173229     9
# 173212     9
# 250001     9
# 122018     8
# 560037     8
# 132036     8
# 560010     8
# 110011     7
# 110008     7
# 201306     7
# 110014     6
# 110018     6
# 201008     5
# 201009     5
# 201305     5
# 201312     5
# 244001     5
# 530068     5
# 201005     4
# 110009     4
# 110042     4
# 110039     4
# 110030     4
# 201304     4
# 122009     4
# 201303     4
# 560018     4
# 201001     4
# 560003     4
# 560002     4
# 560013     3
# 203001     2
# 203207     1
# 560001     1
# 203202     1
# Name: 4 What is the Pin Code of where you shop online from?, dtype: int64

# %%
plt.subplots(figsize=(10,10))
sns.countplot(y="4 What is the Pin Code of where you shop online from?", data=df)
plt.title("Area pincode")
plt.ylabel('pincode')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.5 Time

# %%
df['5 Since How Long You are Shopping Online ?'].value_counts()
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %%
sns.countplot(y="5 Since How Long You are Shopping Online ?", data=df)
plt.title("Time")
plt.ylabel('Years')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.6 Purchases made in one year

# %%
df['6 How many times you have made an online purchase in the past 1 year?'].value_counts()
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %%
sns.countplot(y="6 How many times you have made an online purchase in the past 1 year?", data=df)
plt.title("Number of purchases mde in one year")
plt.ylabel('no. of purchases')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.7 Internet access

# %%
df['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %%
sns.countplot(y="7 How do you access the internet while shopping on-line?", data=df)
plt.title("Internet access")
plt.ylabel('internet access')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.8 Device used

# %%
df['8 Which device do you use to access the online shopping?'].value_counts()
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %%
sns.countplot(y="8 Which device do you use to access the online shopping?", data=df)
plt.title("Device used")
plt.ylabel('Device')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.9 Screen size

# %%
df['9 What is the screen size of your mobile device?						                                        '].value_counts()
# Out:
# Others        134
# 5.5 inches     99
# 4.7 inches     29
# 5 inches        7
# Name: 9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        , dtype: int64

# %%
sns.countplot(y="9 What is the screen size of your mobile device?						                                        ", data=df)
plt.title("Screen size of device")
plt.ylabel('Screen size')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.10 Operating system

# %%
df['10 What is the operating system (OS) of your device?\t\t\t\t                                          '].value_counts()
# Out:
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: 10 What is the operating system (OS) of your device?\t\t\t\t                                          , dtype: int64

# %%
sns.countplot(y="10 What is the operating system (OS) of your device?\t\t\t\t                                          ", data=df)
plt.title("Operating system")
plt.ylabel('OS')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.11 Browser

# %%
df['11 What browser do you run on your device to access the website?\t\t\t                                                          '].value_counts()
# Out:
# Google chrome      216
# Safari              40
# Opera                8
# Mozilla Firefox      5
# Name: 11 What browser do you run on your device to access the website?\t\t\t                                                          , dtype: int64

# %%
#plt.subplots(figsize=(10,10))
sns.countplot(y="11 What browser do you run on your device to access the website?\t\t\t                                                          ", data=df)
plt.title("Browser used")
plt.ylabel('Name of browser')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.12 Channel used

# %%
df['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '].value_counts()
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: 12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   , dtype: int64

# %%
sns.countplot(y="12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ", data=df)
plt.title("Channel used ")
plt.ylabel('Name of channel')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.14 Exploring time

# %%
df['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '].value_counts()
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: 14 How much time do you explore the e- retail store before making a purchase decision?                                                                   , dtype: int64

# %%
sns.countplot(y="14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ", data=df)
plt.title("Exploring time")
plt.ylabel('Time ')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.15 Payment method

# %%
df['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '].value_counts()
# Out:
# Credit/Debit cards                    148
# Cash on delivery (CoD)                 76
# E-wallets (Paytm, Freecharge etc.)     45
# Name: 15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               , dtype: int64

# %%
sns.countplot(y="15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ", data=df)
plt.title("Payment method")
plt.ylabel('Method')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.16 Leaving without payment

# %%
df['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   '].value_counts()
# Out:
# Sometimes          171
# Never               48
# Frequently          35
# Very frequently     15
# Name: 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   , dtype: int64

# %%
sns.countplot(y="16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ", data=df)
plt.title("Leave without payment")
plt.ylabel("options")
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.17 Reason for abandoning page

# %%
df['17 Why did you abandon the �Bag�, �Shopping Cart�?\t\t\t\t\t                                                                                                                                                       '].value_counts()
# Out:
# Better alternative offer        133
# Promo code not applicable        54
# Change in price                  37
# Lack of trust                    31
# No preferred mode of payment     14
# Name: 17 Why did you abandon the �Bag�, �Shopping Cart�?\t\t\t\t\t                                                                                                                                                       , dtype: int64

# %%
sns.countplot(y="17 Why did you abandon the �Bag�, �Shopping Cart�?\t\t\t\t\t                                                                                                                                                       ", data=df)
plt.title("Reason for abandoning car/bag")
plt.ylabel('reason')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.18 Website content qualiity

# %%
df['18 The content on the website must be easy to read and understand'].value_counts()
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: 18 The content on the website must be easy to read and understand, dtype: int64

# %%
sns.countplot(y="18 The content on the website must be easy to read and understand", data=df)
plt.title("Quality of contenton website")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.19 Product comparison

# %%
df['19 Information on similar product to the one highlighted  is important for product comparison'].value_counts()
# Out:
# Strongly agree (5)    116
# Agree (4)              92
# Indifferent (3)        43
# Dis-agree (2)          18
# Name: 19 Information on similar product to the one highlighted  is important for product comparison, dtype: int64

# %%
sns.countplot(y="19 Information on similar product to the one highlighted  is important for product comparison", data=df)
plt.title("Prduct comparison")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.20 Seller information

# %%
df['20 Complete information on listed seller and product being offered is important for purchase decision.'].value_counts()
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: 20 Complete information on listed seller and product being offered is important for purchase decision., dtype: int64

# %%
sns.countplot(y="20 Complete information on listed seller and product being offered is important for purchase decision.", data=df)
plt.title("Seller info")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.21 Relevant information

# %%
df['21 All relevant information on listed products must be stated clearly'].value_counts()
# Out:
# Agree (4)                132
# Strongly agree (5)       107
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Name: 21 All relevant information on listed products must be stated clearly, dtype: int64

# %%
sns.countplot(y="21 All relevant information on listed products must be stated clearly", data=df)
plt.title("Relevant information")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.22 Navigation

# %%
df['22 Ease of navigation in website'].value_counts()
# Out:
# Strongly agree (5)       141
# Agree (4)                105
# Strongly disagree (1)     18
# Dis-agree (2)              5
# Name: 22 Ease of navigation in website, dtype: int64

# %%
sns.countplot(y="22 Ease of navigation in website", data=df)
plt.title("Navigation")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.23 Navigation speed

# %%
df['23 Loading and processing speed'].value_counts()
# Out:
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Indifferent (3)           12
# Strongly disagree (1)     12
# Name: 23 Loading and processing speed, dtype: int64

# %%
sns.countplot(y="23 Loading and processing speed", data=df)
plt.title("Speed")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.24 User Interface

# %%
df['24 User friendly Interface of the website'].value_counts()
# Out:
# Strongly agree (5)       189
# Agree (4)                 45
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Indifferent (3)            5
# Name: 24 User friendly Interface of the website, dtype: int64

# %%
sns.countplot(y="24 User friendly Interface of the website", data=df)
plt.title("User interface")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.25 Payment methods

# %%
df['25 Convenient Payment methods'].value_counts()
# Out:
# Strongly agree (5)    159
# Agree (4)              80
# Dis-agree (2)          30
# Name: 25 Convenient Payment methods, dtype: int64

# %%
sns.countplot(y="25 Convenient Payment methods", data=df)
plt.title("Payment method")
plt.ylabel('Options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.26 Trust

# %%
df['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'].value_counts()
# Out:
# Strongly agree (5)    141
# Agree (4)              86
# Disagree (2)           30
# indifferent  (3)       12
# Name: 26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time, dtype: int64

# %%
sns.countplot(y="26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time", data=df)
plt.title("Trust")
plt.ylabel('Options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.27 Emapthy

# %%
df['27 Empathy (readiness to assist with queries) towards the customers'].value_counts()
# Out:
# Strongly agree (5)       194
# Agree (4)                 42
# Strongly disagree (1)     18
# indifferent (3)           15
# Name: 27 Empathy (readiness to assist with queries) towards the customers, dtype: int64

# %%
sns.countplot(y="27 Empathy (readiness to assist with queries) towards the customers", data=df)
plt.title("Empathy")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.28 Privacy

# %%
df['28 Being able to guarantee the privacy of the customer'].value_counts()
# Out:
# Strongly agree (5)    185
# Agree (4)              58
# indifferent (3)        26
# Name: 28 Being able to guarantee the privacy of the customer, dtype: int64

# %%
sns.countplot(y="28 Being able to guarantee the privacy of the customer", data=df)
plt.title("Privacy gurantee")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.29 Responsiveness

# %%
df['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'].value_counts()
# Out:
# Strongly agree (5)       149
# Agree (4)                 94
# indifferent (3)           15
# Strongly disagree (1)     11
# Name: 29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.), dtype: int64

# %%
sns.countplot(y="29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)", data=df)
plt.title("Responsiveness")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.30 Monetray benefits

# %%
df['30 Online shopping gives monetary benefit and discounts'].value_counts()
# Out:
# Strongly agree (5)       105
# Agree (4)                 85
# indifferent (3)           50
# Strongly disagree (1)     18
# Dis-agree (2)             11
# Name: 30 Online shopping gives monetary benefit and discounts, dtype: int64

# %%
sns.countplot(y="30 Online shopping gives monetary benefit and discounts", data=df)
plt.title("Discounts")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.31 Enjoyment

# %%
df['31 Enjoyment is derived from shopping online'].value_counts()
# Out:
# Strongly agree (5)       86
# indifferent (3)          75
# Agree (4)                59
# Strongly disagree (1)    30
# Dis-agree (2)            19
# Name: 31 Enjoyment is derived from shopping online, dtype: int64

# %%
sns.countplot(y="31 Enjoyment is derived from shopping online", data=df)
plt.title("Enjoyment")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.32 Convinience

# %%
df['32 Shopping online is convenient and flexible'].value_counts()
# Out:
# Strongly agree (5)    146
# Agree (4)              78
# indifferent (3)        33
# Dis-agree (2)          12
# Name: 32 Shopping online is convenient and flexible, dtype: int64

# %%
sns.countplot(y="32 Shopping online is convenient and flexible", data=df)
plt.title("Convinience")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.33 Return policy

# %%
df['33 Return and replacement policy of the e-tailer is important for purchase decision'].value_counts()
# Out:
# Strongly agree (5)    198
# Agree (4)              51
# Dis-agree (2)          20
# Name: 33 Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64

# %%
sns.countplot(y="33 Return and replacement policy of the e-tailer is important for purchase decision", data=df)
plt.title("Return policy")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.34 Loyality program as benefit

# %%
df['34 Gaining access to loyalty programs is a benefit of shopping online'].value_counts()
# Out:
# Strongly agree (5)       115
# indifferent (3)           64
# Agree (4)                 64
# Dis-agree (2)             15
# Strongly disagree (1)     11
# Name: 34 Gaining access to loyalty programs is a benefit of shopping online, dtype: int64

# %%
sns.countplot(y="34 Gaining access to loyalty programs is a benefit of shopping online", data=df)
plt.title("Loyality program as benefit")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.35 Information quality

# %%
df['35 Displaying quality Information on the website improves satisfaction of customers'].value_counts()
# Out:
# Strongly agree (5)    133
# Agree (4)              80
# indifferent (3)        56
# Name: 35 Displaying quality Information on the website improves satisfaction of customers, dtype: int64

# %%
sns.countplot(y="35 Displaying quality Information on the website improves satisfaction of customers", data=df)
plt.title("Information quality")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.36 Satisfaction

# %%
df['36 User derive satisfaction while shopping on a good quality website or application'].value_counts()
# Out:
# Strongly agree (5)    175
# Agree (4)              86
# Dis-agree (2)           8
# Name: 36 User derive satisfaction while shopping on a good quality website or application, dtype: int64

# %%
sns.countplot(y="36 User derive satisfaction while shopping on a good quality website or application", data=df)
plt.title("Satisfaction")

plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.37 Net benefit

# %%
df['37 Net Benefit derived from shopping online can lead to users satisfaction'].value_counts()
# Out:
# Strongly agree (5)    164
# Agree (4)              54
# indifferent (3)        40
# Dis-agree (2)          11
# Name: 37 Net Benefit derived from shopping online can lead to users satisfaction, dtype: int64

# %%
sns.countplot(y="37 Net Benefit derived from shopping online can lead to users satisfaction", data=df)
plt.title("Net benefit")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.38 Trust and satisfaction

# %%
df['38 User satisfaction cannot exist without trust'].value_counts()
# Out:
# Strongly agree (5)       122
# Agree (4)                117
# Strongly disagree (1)     18
# Dis-agree (2)              7
# indifferent (3)            5
# Name: 38 User satisfaction cannot exist without trust, dtype: int64

# %%
sns.countplot(y="38 User satisfaction cannot exist without trust", data=df)
plt.title("Trust and satisfaction")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.39 Variety

# %%
df['39 Offering a wide variety of listed product in several category'].value_counts()
# Out:
# Strongly agree (5)    111
# Agree (4)              94
# indifferent (3)        57
# Dis-agree (2)           7
# Name: 39 Offering a wide variety of listed product in several category, dtype: int64

# %%
sns.countplot(y="39 Offering a wide variety of listed product in several category", data=df)
plt.title("Variety")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.40 Relevant information

# %%
df['40 Provision of complete and relevant product information'].value_counts()
# Out:
# Strongly agree (5)    135
# Agree (4)              98
# indifferent (3)        31
# Disagree (2)            5
# Name: 40 Provision of complete and relevant product information, dtype: int64

# %%
sns.countplot(y="40 Provision of complete and relevant product information", data=df)
plt.title("Relevant information")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.41 Savings

# %%
df['41 Monetary savings'].value_counts()
# Out:
# Strongly agree (5)    148
# Agree (4)              75
# Disagree (2)           31
# indifferent (3)        15
# Name: 41 Monetary savings, dtype: int64

# %%
sns.countplot(y="41 Monetary savings", data=df)
plt.title("Savings")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.42 The Convenience of patronizing the online retailer

# %%
df['42 The Convenience of patronizing the online retailer'].value_counts()
# Out:
# Agree (4)             138
# indifferent (3)        77
# Strongly agree (5)     54
# Name: 42 The Convenience of patronizing the online retailer, dtype: int64

# %%
sns.countplot(y="42 The Convenience of patronizing the online retailer", data=df)
plt.title("The Convenience of patronizing the online retailer")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.43 Excitement factor

# %%
df['43 Shopping on the website gives you the sense of adventure'].value_counts()
# Out:
# Agree (4)                101
# indifferent (3)           59
# Strongly agree (5)        54
# Dis-agree (2)             50
# Strongly disagree (1)      5
# Name: 43 Shopping on the website gives you the sense of adventure, dtype: int64

# %%
sns.countplot(y="43 Shopping on the website gives you the sense of adventure", data=df)
plt.title("Adventurous shopping ")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.44 Social status

# %%
df['44 Shopping on your preferred e-tailer enhances your social status'].value_counts()
# Out:
# indifferent (3)          100
# Agree (4)                 59
# Strongly agree (5)        48
# Strongly disagree (1)     33
# Dis-agree (2)             29
# Name: 44 Shopping on your preferred e-tailer enhances your social status, dtype: int64

# %%
sns.countplot(y="44 Shopping on your preferred e-tailer enhances your social status", data=df)
plt.title("Social status")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.45 Gratification

# %%
df['45 You feel gratification shopping on your favorite e-tailer'].value_counts()
# Out:
# indifferent (3)          101
# Strongly agree (5)        65
# Agree (4)                 63
# Disagree (2)              22
# Strongly disagree (1)     18
# Name: 45 You feel gratification shopping on your favorite e-tailer, dtype: int64

# %%
sns.countplot(y="45 You feel gratification shopping on your favorite e-tailer", data=df)
plt.title("Gratification")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.46 Fulfil certain roles

# %%
df['46 Shopping on the website helps you fulfill certain roles'].value_counts()
# Out:
# indifferent (3)          88
# Agree (4)                88
# Strongly agree (5)       38
# Strongly disagree (1)    33
# Dis-agree (2)            22
# Name: 46 Shopping on the website helps you fulfill certain roles, dtype: int64

# %%
sns.countplot(y="46 Shopping on the website helps you fulfill certain roles", data=df)
plt.title("Fulfilment of certain roles")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.47 Value for spent money

# %%
df['47 Getting value for money spent'].value_counts()
# Out:
# Agree (4)             149
# Strongly agree (5)     82
# indifferent (3)        38
# Name: 47 Getting value for money spent, dtype: int64

# %%
sns.countplot(y="47 Getting value for money spent", data=df)
plt.title("Value for spent money")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# 5.48 FEEDBACK QUESTIONS

# %%
df['Easy to use website or application'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         44
# Amazon.in                                                       29
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                22
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Flipkart.com, Myntra.com                             19
# Paytm.com                                                       12
# Flipkart.com                                                     8
# Amazon.in, Paytm.com                                             7
# Name: Easy to use website or application, dtype: int64

# %%
sns.countplot(y="Easy to use website or application", data=df)
plt.title("Ease of use")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# Variety

# %%
df['Wild variety of product on offer'].value_counts()
# Out:
# Amazon.in, Flipkart.com                              130
# Amazon.in                                             43
# Amazon.in, Myntra.com                                 20
# Flipkart.com, Myntra.com                              15
# Myntra.com                                            15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     14
# Amazon.in, Flipkart.com, Paytm.com                    13
# Flipkart.com                                          12
# Paytm.com                                              7
# Name: Wild variety of product on offer, dtype: int64

# %%
sns.countplot(y="Wild variety of product on offer", data=df)
plt.title("Variety")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# Description

# %%
df['Complete, relevant description information of products'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         100
# Amazon.in                                                        43
# Amazon.in, Flipkart.com, Paytm.com                               24
# Amazon.in, Paytm.com, Myntra.com                                 20
# Amazon.in, Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                14
# Snapdeal.com                                                     12
# Flipkart.com, Snapdeal.com                                       11
# Flipkart.com                                                      8
# Amazon.in, Flipkart.com, Snapdeal.com                             7
# Name: Complete, relevant description information of products, dtype: int64

# %%
sns.countplot(y="Complete, relevant description information of products", data=df)
plt.title("Description")
plt.ylabel('')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# Loading of website

# %%
df['Fast loading website speed of website and application'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Fast loading website speed of website and application, dtype: int64

# %%
sns.countplot(y="Fast loading website speed of website and application", data=df)
plt.title("Loading of website")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# Reliability

# %%
df['Reliability of the website or application'].value_counts()
# Out:
# Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Flipkart.com                                         15
# Myntra.com                                           15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability of the website or application, dtype: int64

# %%
sns.countplot(y="Reliability of the website or application", data=df)
plt.title("Reliability")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# Quickness

# %%
df['Quickness to complete purchase'].value_counts()
# Out:
# Amazon.com                                                   66
# Amazon.com, Flipkart.com, Paytm.com                          47
# Amazon.com, Flipkart.com                                     37
# Amazon.com, Flipkart.com, Myntra.com                         30
# Paytm.com                                                    25
# Amazon.com, Paytm.com, Myntra.com                            20
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal    15
# Flipkart.com                                                 15
# Flipkart.com, Myntra.com, Snapdeal                           14
# Name: Quickness to complete purchase, dtype: int64

# %%
sns.countplot(y="Quickness to complete purchase", data=df)
plt.title("Quickness")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# Variation in payment method

# %%
df['Availability of several payment options'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         65
# Amazon.in, Flipkart.com, Myntra.com                             40
# Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com    39
# Amazon.in                                                       23
# Patym.com, Myntra.com                                           20
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               19
# Amazon.in, Flipkart.com, Snapdeal.com                           18
# Flipkart.com, Myntra.com, Snapdeal.com                          14
# Patym.com                                                       12
# Amazon.in, Patym.com                                            11
# Flipkart.com                                                     8
# Name: Availability of several payment options, dtype: int64

# %%
sns.countplot(y="Availability of several payment options", data=df)
plt.title("Availibility")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# Delivery timing

# %%
df['Speedy order delivery '].value_counts()
# Out:
# Amazon.in                                 107
# Amazon.in, Flipkart.com                    82
# Amazon.in, Flipkart.com, Snapdeal.com      36
# Flipkart.com                               15
# Amazon.in, Flipkart.com, Myntra.com        15
# Flipkart.com, Myntra.com, Snapdeal.com     14
# Name: Speedy order delivery , dtype: int64

# %%
sns.countplot(y="Speedy order delivery ", data=df)
plt.title("Delivery timing")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# Privacy  of information

# %%
df['Privacy of customers� information'].value_counts()
# Out:
# Amazon.in                                                       71
# Amazon.in, Flipkart.com                                         54
# Amazon.in, Flipkart.com, Myntra.com                             25
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    24
# Paytm.com                                                       18
# Flipkart.com                                                    15
# Myntra.com                                                      15
# Amazon.in, Paytm.com                                            15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Amazon.in, Flipkart.com, Snapdeal.com                            7
# Name: Privacy of customers� information, dtype: int64

# %%
sns.countplot(y="Privacy of customers� information", data=df)
plt.title("Privacy")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# Security of financial information

# %%
df['Security of customer financial information'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    42
# Flipkart.com                                                    33
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com                                         24
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Snapdeal.com                                         19
# Myntra.com                                                      15
# Paytm.com                                                       15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Security of customer financial information, dtype: int64

# %%
sns.countplot(y="Security of customer financial information", data=df)
plt.title("Security of financial information")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# Trustworthiness

# %%
df['Perceived Trustworthiness'].value_counts()
# Out:
# Amazon.in                                                       76
# Amazon.in, Flipkart.com, Snapdeal.com                           36
# Amazon.in, Myntra.com                                           35
# Amazon.in, Flipkart.com                                         31
# Flipkart.com                                                    27
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               25
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    13
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Perceived Trustworthiness, dtype: int64

# %%
sns.countplot(y="Perceived Trustworthiness", data=df)
plt.title("Trust")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# Online assistance

# %%
df['Presence of online assistance through multi-channel'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal    61
# Amazon.in                                        60
# Amazon.in, Flipkart.com                          39
# Amazon.in, Snapdeal                              26
# Myntra.com                                       20
# Amazon.in, Myntra.com                            15
# Amazon.in, Flipkart.com, Myntra.com              15
# Amazon.in, Flipkart.com, Paytm.com               13
# Paytm.com                                        12
# Flipkart.com                                      8
# Name: Presence of online assistance through multi-channel, dtype: int64

# %%
sns.countplot(y="Presence of online assistance through multi-channel", data=df)
plt.title("Online assistance")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# Logging in timing

# %%
df['Longer time to get logged in (promotion, sales period)'].value_counts()
# Out:
# Amazon.in                                57
# Amazon.in, Flipkart.com                  38
# Paytm.com                                38
# Myntra.com                               35
# Amazon.in, Flipkart.com, Snapdeal.com    29
# Snapdeal.com                             25
# Flipkart.com, Paytm.com                  15
# Flipkart.com, Paytm.com, Snapdeal.com    13
# Amazon.in, Paytm.com                     11
# Flipkart.com                              8
# Name: Longer time to get logged in (promotion, sales period), dtype: int64

# %%
sns.countplot(y="Longer time to get logged in (promotion, sales period)", data=df)
plt.title("Logging in timing")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# Graphic display

# %%
df['Longer time in displaying graphics and photos (promotion, sales period)'].value_counts()
# Out:
# Amazon.in, Flipkart.com                60
# Amazon.in                              39
# Myntra.com                             35
# Snapdeal.com                           34
# Myntra.com, Snapdeal.com               25
# Flipkart.com, Snapdeal.com             19
# Flipkart.com                           15
# Paytm.com                              15
# Amazon.in, Myntra.com, Snapdeal.com    14
# Amazon.in, Paytm.com                   13
# Name: Longer time in displaying graphics and photos (promotion, sales period), dtype: int64

# %%
sns.countplot(y="Longer time in displaying graphics and photos (promotion, sales period)", data=df)
plt.title("Graphic display")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# Late declaration time

# %%
df['Late declaration of price (promotion, sales period)'].value_counts()
# Out:
# Myntra.com                 75
# Paytm.com                  52
# snapdeal.com               41
# Flipkart.com               38
# Amazon.in                  38
# Amazon.in, Paytm.com       13
# Paytm.com, snapdeal.com     7
# Amazon.in, Flipkart.com     5
# Name: Late declaration of price (promotion, sales period), dtype: int64

# %%
sns.countplot(y="Late declaration of price (promotion, sales period)", data=df)
plt.title("Late declaration in price")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# Longer page loading time

# %%
df['Longer page loading time (promotion, sales period)'].value_counts()
# Out:
# Myntra.com                          61
# Paytm.com                           59
# Flipkart.com                        32
# Snapdeal.com                        23
# Amazon.in, Flipkart.com             18
# Amazon.in                           16
# Paytm.com, Snapdeal.com             15
# Amazon.in, Snapdeal.com             14
# Amazon.in, Paytm.com                13
# Flipkart.com, Snapdeal.com          11
# Amazon.in, Paytm.com, Myntra.com     7
# Name: Longer page loading time (promotion, sales period), dtype: int64

# %%
sns.countplot(y="Longer page loading time (promotion, sales period)", data=df)
plt.title("Longer page loading time")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# Limited mode of payment

# %%
df['Limited mode of payment on most products (promotion, sales period)'].value_counts()
# Out:
# Snapdeal.com                87
# Amazon.in                   62
# Flipkart.com                31
# Amazon.in, Flipkart.com     29
# Paytm.com                   25
# Paytm.com, Snapdeal.com     15
# Amazon.in, Paytm.com        13
# Myntra.com, Snapdeal.com     7
# Name: Limited mode of payment on most products (promotion, sales period), dtype: int64

# %%
sns.countplot(y="Limited mode of payment on most products (promotion, sales period)", data=df)
plt.title("Limited mode of payment")
plt.ylabel('')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# Longer delivery period

# %%
df['Longer delivery period'].value_counts()
# Out:
# Paytm.com                  72
# Snapdeal.com               64
# Flipkart.com               44
# Amazon.in                  37
# Myntra.com                 26
# Paytm.com, Snapdeal.com    26
# Name: Longer delivery period, dtype: int64

# %%
sns.countplot(y="Longer delivery period", data=df)
plt.title("Longer delivery time")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# Change in design of application

# %%
df['Change in website/Application design'].value_counts()
# Out:
# Amazon.in                   96
# Paytm.com                   63
# Amazon.in, Flipkart.com     45
# Myntra.com                  30
# Flipkart.com                20
# Snapdeal.com                 8
# Flipkart.com, Myntra.com     7
# Name: Change in website/Application design, dtype: int64

# %%
sns.countplot(y="Change in website/Application design", data=df)
plt.title("Change in website design")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# Disruption

# %%
df['Frequent disruption when moving from one page to another'].value_counts()
# Out:
# Amazon.in                     53
# Myntra.com                    52
# Snapdeal.com                  49
# Paytm.com                     39
# Flipkart.com                  26
# Amazon.in, Flipkart.com       25
# Myntra.com, Snapdeal.com      14
# Flipkart.com, Snapdeal.com    11
# Name: Frequent disruption when moving from one page to another, dtype: int64

# %%
sns.countplot(y="Frequent disruption when moving from one page to another", data=df)
plt.title("Disruption while using website")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# Efficiency comparison

# %%
df['Website is as efficient as before'].value_counts()
# Out:
# Amazon.in                             94
# Flipkart.com                          47
# Amazon.in, Flipkart.com               45
# Amazon.in, Flipkart.com, Paytm.com    25
# Amazon.in, Paytm.com                  18
# Paytm.com                             15
# Myntra.com, Snapdeal.com              14
# Snapdeal.com                          11
# Name: Website is as efficient as before, dtype: int64

# %%
sns.countplot(y="Website is as efficient as before", data=df)
plt.title("Efficiency improvement")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# Recommendation of an Indian retailer

# %%
df['Which of the Indian online retailer would you recommend to a friend?'].value_counts()
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %%
sns.countplot(y="Which of the Indian online retailer would you recommend to a friend?", data=df)
plt.title("Recommendation of Indian retailer")
plt.ylabel('options')
plt.xlabel("count")
plt.grid()
plt.show()

# %% [markdown]
# ## 6. Observations

# %% [markdown]
# 1. SHOPPER'S DETAILS(maximum people who shop online come in these categories)
#     • Gender - Female(value count = 181)
#     • Age group - 31-40 years (value count = 81)
#     • Area(city) - Delhi (value count = 58)
#     • Area(pincode) - 201308 (value count = 38)
#
# <br>
#
# 2. Although people may surf online shopping portals but most of them have made less than 10 purchases in a year
#
# <br>
#
# 3. Most common surfing method
#     • Internet access - Mobile internet(value count = 189)
#     • Device - Smartphone (value count = 141)
#     • Operating system - Windows (value count = 122)
#     • Browser - Google chrome (value count = 216)
#     • Payment method - Cards
#
# <br>
#
# 4. Most of the people **SOMETIMES** leave without making payment for which the most common reason is that they **get better alternative option**
#
# <br>
#
# 5. Most of the people **STRONGLY AGREE** on following points-
#     • The content on the website must be easy to read and understand
#     • Information on similar product to the one highlighted  is important for product comparison
#     • There is ease of navigation in website
#     • There is ample loading and processing speed
#     • Websites have friendly user interface
#     • Convenient Payment methods are avaliable on websites
#     • Trust that the online retail store will fulfill its part of the transaction at the stipulated time
#     • Websites show empathy towards the customers
#     • Websites guarantee the privacy of the customer
#     • There is availability of several communication channels (email, online rep, twitter, phone etc.)
#     • Online shopping gives people monetary benefit and discounts
#     • They derive enjoyment while shopping online
#     • Shopping online is convenient and flexible
#     • Return and replacement policy of the e-tailer is important for purchase decision
#     • Gaining access to loyalty programs is a benefit of shopping online
#     • Displaying quality Information on the website improves satisfaction of customers
#     • User derive satisfaction while shopping on a good quality website or application
#     • Net Benefit derived from shopping online can lead to users satisfaction
#     • User satisfaction cannot exist without trust
#     • Offering a wide variety of listed product in several category
#     • Provision of complete and relevant product information
#     • Monetary savings
#     • Shopping on the website helps you fulfill certain roles
#     • Getting value for money spent
#
# <br>
#
#
#
# 6. Most of the people **JUST AGREE** on following points-
#     • All relevant information on listed products must be stated clearly
#     • The Convenience of patronizing the online retailer
#     • Shopping on the website gives you the sense of adventure
#
# <br>
#
#
#
#
# 7. Most of the people JUST AGREE on following points-
#     • Shopping on your preferred e-tailer enhances your social status
#     • You feel gratification shopping on your favorite e-tailer
#
#
# <br>
#
# 8. Majority of the people have chosen Amazon for Fast loading, reliability, quickness, speedy delivery, privacy and financial information, trust and longer time in loading products at the time of sale
#
# <br>
#
# 9. In many cases people have chosen Amazon and flipkart for variety in offers, relevent description and information of seller and item, variation of payment and online assistance.
#
# <br>
#
# 10. People have chosen almost all the websites as easy to use.
#
# <br>
